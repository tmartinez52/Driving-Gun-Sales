# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import csv and convert to pandas dataframe
gtrends_csv = "../keyword_data/2014-2019-07-31_GTrends.csv"
gtrends_df = pd.read_csv(gtrends_csv)
gtrends_df.head()
# Out:
#      Month  Relative Value
# 0  2014-01              25
# 1  2014-02              18
# 2  2014-03              18
# 3  2014-04              24
# 4  2014-05              25

# %%
# Set x axis to numerical value for month
x_axis_data = gtrends_df["Month"]

# %%
# Relative value of searches for the word "shooting"
searches = gtrends_df["Relative Value"]

# %%
# Plot the line
#plt.plot(x_axis_data, searches)
#plt.show()

# %%
gtrends_df.plot(kind="line", x="Month", y="Relative Value", figsize=(16,6),
              title='Google Search Count for "shooting": 2014-01 to 2019-07')
plt.grid(axis='y')

# Save Figure
plt.savefig("../Images/gtrends.png")

plt.show()
