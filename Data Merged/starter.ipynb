# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mj_load="Resources/Mother Jones_Mass Shootings.csv"
gv_load='Resources/gun_violence_final.csv'
mj_df=pd.read_csv(mj_load)
gv_df=pd.read_csv(gv_load)

# %%
mj_df.head()
# Out:
#    Incident_ID                            case             MJ_location  \
# 0        50100           Cascade Mall shooting  Burlington, Washington
# 1        50188     Baton Rouge police shooting   Baton Rouge, Lousiana
# 2        50205          Dallas police shooting           Dallas, Texas
# 3        50246      Orlando nightclub massacre        Orlando, Florida
# 4        50348  Excel Industries mass shooting         Hesston, Kansas
#
#      MJ_date                                            summary  \
# 0  9/23/2016  Arcan Cetin, 20, killed a teen girl and three ...
# 1  7/17/2016  Gavin Long, 29, a former Marine who served in ...
# 2   7/7/2016  Micah Xavier Johnson, a 25-year-old Army veter...
# 3  6/12/2016  Omar Mateen, 29, attacked the Pulse nighclub i...
# 4  2/25/2016  Cedric L. Ford, who worked as a painter at a m...
#
#    MJ_fatalities  MJ_injured  MJ_total_victims MJ_loc_type  age_of_shooter  \
# ...

# %%
gv_df.head()

# %%
gv_df["TotalVictim"]=gv_df["# Killed"]+gv_df["# Injured"]
gv_df.head()

# %%
gv_df=gv_df[gv_df.TotalVictim > 4]
gv_df.head()
# Out:
#    Incident_ID Incident Date        State City Or County  \
# 2        50002     30-Dec-16         Ohio      Mansfield
# 3        50003     30-Dec-16  Connecticut    Wallingford
# 4        50004     28-Dec-16      Georgia       Columbus
# 5        50005     25-Dec-16     Illinois        Chicago
# 7        50007     25-Dec-16     New York   Mount Vernon
#
#                         Address  # Killed  # Injured  TotalVictim
# 2            3230 Possum Run Rd         0          5            5
# 3              95 S Turnpike Rd         2          3            5
# 4              2914 10th Street         1          4            5
# 5  8600 block of S Maryland Ave         3          4            7
# 7            4 North 3rd Avenue         1          5            6

# %%
#gv_df.to_csv("gun_violence_5.csv", index=False, header=True)

# %%
gv_load_data="gun_violence_5.csv"
gv_df_2=pd.read_csv(gv_load_data)
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Jan", "01")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Feb", "02")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Mar", "03")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Apr", "04")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("May", "05")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Jun", "06")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Jul", "07")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Aug", "08")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Sep", "09")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Oct", "10")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Nov", "11")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("Dec", "12")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("14", "2014")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("15", "2015")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("16", "2016")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("17", "2017")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("18", "2018")
gv_df_2["Incident Date"]=gv_df_2["Incident Date"].str.replace("19", "2019")
gv_df_2.head()
# Out:
#    Incident_ID Incident Date        State City Or County  \
# 0        50002    30-12-2016         Ohio      Mansfield
# 1        50003    30-12-2016  Connecticut    Wallingford
# 2        50004    28-12-2016      Georgia       Columbus
# 3        50005    25-12-2016     Illinois        Chicago
# 4        50007    25-12-2016     New York   Mount Vernon
#
#                         Address  # Killed  # Injured  TotalVictim
# 0            3230 Possum Run Rd         0          5            5
# 1              95 S Turnpike Rd         2          3            5
# 2              2914 10th Street         1          4            5
# 3  8600 block of S Maryland Ave         3          4            7
# 4            4 North 3rd Avenue         1          5            6

# %%
new_1 = gv_df_2["Incident Date"].str.split("-", n = 2, expand = True)
gv_df_2["Month/Year"]=new_1[2]+new_1[1]
gv_df_2.head()
# Out:
#    Incident_ID Incident Date        State City Or County  \
# 0        50002    30-12-2016         Ohio      Mansfield
# 1        50003    30-12-2016  Connecticut    Wallingford
# 2        50004    28-12-2016      Georgia       Columbus
# 3        50005    25-12-2016     Illinois        Chicago
# 4        50007    25-12-2016     New York   Mount Vernon
#
#                         Address  # Killed  # Injured  TotalVictim Month/Year
# 0            3230 Possum Run Rd         0          5            5     201612
# 1              95 S Turnpike Rd         2          3            5     201612
# 2              2914 10th Street         1          4            5     201612
# 3  8600 block of S Maryland Ave         3          4            7     201612
# 4            4 North 3rd Avenue         1          5            6     201612

# %%
gv_df_2=gv_df_2.sort_values('Month/Year', ascending = True)
gv_df_2.head()
# Out:
#      Incident_ID Incident Date       State City Or County  \
# 600        97407  2016-01-2014    Oklahoma        Ardmore
# 597        95550    12-01-2014     Alabama     Huntsville
# 598        95579    12-01-2014    Illinois          Elgin
# 599        97365  2016-01-2014        Utah   Spanish Fork
# 618       113665    27-01-2014  Washington        Seattle
#
#                                     Address  # Killed  # Injured  TotalVictim  \
# 600     H St NE and Martin Luther King Blvd         2          5            7
# 597                        University Drive         0          5            5
# 598               300 block of North Street         0          5            5
# 599                          37 N. 630 West         5          0            5
# 618  2nd Avenue South and South Main Street         1          4            5
#
#     Month/Year
# 600     201401
# 597     201401
# 598     201401
# 599     201401
# 618     201401

# %%
gv_df_2["Year"]=new_1[2]
gv_df_2.head()
# Out:
#      Incident_ID Incident Date       State City Or County  \
# 600        97407  2016-01-2014    Oklahoma        Ardmore
# 597        95550    12-01-2014     Alabama     Huntsville
# 598        95579    12-01-2014    Illinois          Elgin
# 599        97365  2016-01-2014        Utah   Spanish Fork
# 618       113665    27-01-2014  Washington        Seattle
#
#                                     Address  # Killed  # Injured  TotalVictim  \
# 600     H St NE and Martin Luther King Blvd         2          5            7
# 597                        University Drive         0          5            5
# 598               300 block of North Street         0          5            5
# 599                          37 N. 630 West         5          0            5
# 618  2nd Avenue South and South Main Street         1          4            5
#
#     Month/Year  Year
# 600     201401  2014
# 597     201401  2014
# 598     201401  2014
# 599     201401  2014
# 618     201401  2014

# %%
gv_df_2["Year"].value_counts()
# Out:
# 2016    164
# 2018    161
# 2015    152
# 2017    138
# 2019    133
# 2014    131
# Name: Year, dtype: int64

# %%
#gv_df_2.to_csv("gun_violence_final.csv", index=False, header=True)

# %%
gv_df_2["Year"].unique()
# Out:
# array(['2014', '2015', '2016', '2017', '2018', '2019'], dtype=object)

# %%
incident_number=[131,152,164,138,161,133]

# %%
plt.bar(gv_df_2["Year"].unique(),incident_number , color="b", align="center")
plt.title("#Incident")
#plt.savefig("IncidentNumber.png")

# %%
gv_df_2["State"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dc10cc14c1af> in <module>
# ----> 1 gv_df_2["State"].value_counts()
#
# NameError: name 'gv_df_2' is not defined

# %%
new = mj_df["MJ_location"].str.split(",", n = 1, expand = True)
mj_df["city"]=new[0]
mj_df["state"]=new[1]

# %%
mj_df=mj_df[mj_df.MJ_year > 2013]
mj_df
# Out:
#     Incident_ID                                           case  \
# 0         50100                          Cascade Mall shooting
# 1         50188                    Baton Rouge police shooting
# 2         50205                         Dallas police shooting
# 3         50246                     Orlando nightclub massacre
# 4         50348                 Excel Industries mass shooting
# 5         50354                       Kalamazoo shooting spree
# 6         60027                   Rancho Tehama shooting spree
# 7         60037            Texas First Baptist Church massacre
# 8         60057                Edgewood businees park shooting
# 9         60071                       Las Vegas Strip massacre
# 10        60188                     San Francisco UPS shooting
# 11        60199           Florida awning manufacturer shooting
# 12        70030               Thousand Oaks nightclub shooting
# 13        70042                Tree of Life synagogue shooting
# ...

# %%
mj_df["state"]=mj_df["state"].str.replace("CA","California")
mj_df["state"]=mj_df["state"].str.replace("TX","Texas")
mj_df["state"]=mj_df["state"].str.replace("PA","Pennsylvania")
mj_df["state"]=mj_df["state"].str.replace("MD","Maryland")
mj_df["state"]=mj_df["state"].str.replace("IL","Illinois")
mj_df["state"]=mj_df["state"].str.replace("OH","Ohio")
mj_df["state"]=mj_df["state"].str.replace("FL","Florida")
mj_df["state"]=mj_df["state"].str.replace("D.C.","District of Columbia")
mj_df["state"]=mj_df["state"].str.replace("CO","Colorado")
mj_df["state"]=mj_df["state"].str.replace("VA","Virginia")
mj_df["state"]=mj_df["state"].str.replace("NV","Nevada")
mj_df["state"]=mj_df["state"].str.replace("TN","Tennessee")
mj_df
# Out:
#     Incident_ID                                           case  \
# 0         50100                          Cascade Mall shooting
# 1         50188                    Baton Rouge police shooting
# 2         50205                         Dallas police shooting
# 3         50246                     Orlando nightclub massacre
# 4         50348                 Excel Industries mass shooting
# 5         50354                       Kalamazoo shooting spree
# 6         60027                   Rancho Tehama shooting spree
# 7         60037            Texas First Baptist Church massacre
# 8         60057                Edgewood businees park shooting
# 9         60071                       Las Vegas Strip massacre
# 10        60188                     San Francisco UPS shooting
# 11        60199           Florida awning manufacturer shooting
# 12        70030               Thousand Oaks nightclub shooting
# 13        70042                Tree of Life synagogue shooting
# ...

# %%
#mj_df.to_csv("Resources/mj_cleaned.csv", index=False, header=True)

# %%
mj_df_10=mj_df.sort_values('MJ_year', ascending = True)
mj_df_10["MJ_year"].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
grouped_year_mj=mj_df_10.groupby("MJ_year")

# %%
grouped_year_mj["Incident_ID"].count()
# Out:
# MJ_year
# 2014     4
# 2015     7
# 2016     6
# 2017    11
# 2018    12
# 2019     8
# Name: Incident_ID, dtype: int64

# %%
incident_val=grouped_year_mj["Incident_ID"].count()
incident_val
# Out:
# MJ_year
# 2014     4
# 2015     7
# 2016     6
# 2017    11
# 2018    12
# 2019     8
# Name: Incident_ID, dtype: int64

# %%
plt.bar(mj_df_10["MJ_year"].unique(),incident_val , color="b", align="center")
plt.title("#Incident")
plt.savefig("IncidentNumber.png")
plt.grid()
#plt.savefig("Images/IncidentNumber_mj_data.png")

# %%
mj_df["state"].value_counts()
# Out:
#  California        10
#  Texas              6
#  Florida            5
#  Pennsylvania       4
#  Ohio               3
#  Maryland           3
#  Colorado           3
#  Washington         2
#  Tennessee          2
#  Illinois           2
#  Virginia           1
#  South Carolina     1
#  Wisconsin          1
#  Oregon             1
#  Michigan           1
#  Lousiana           1
#  Kansas             1
#  Nevada             1
# Name: state, dtype: int64

# %%
grouped_data=mj_df.groupby("state")
grouped_data.count().head()
# Out:
#              Incident_ID  case  MJ_location  MJ_date  summary  MJ_fatalities  \
# state
#  California           10    10           10       10       10             10
#  Colorado              3     3            3        3        3              3
#  Florida               5     5            5        5        5              5
#  Illinois              2     2            2        2        2              2
#  Kansas                1     1            1        1        1              1
#
#              MJ_injured  MJ_total_victims  MJ_loc_type  age_of_shooter  ...  \
# state                                                                   ...
#  California          10                10           10              10  ...
#  Colorado             3                 3            3               3  ...
#  Florida              5                 5            5               5  ...
#  Illinois             2                 2            2               2  ...
# ...

# %%
grouped_data["state"].unique().head()
# Out:
# state
#  California    [ California]
#  Colorado        [ Colorado]
#  Florida          [ Florida]
#  Illinois        [ Illinois]
#  Kansas            [ Kansas]
# Name: state, dtype: object

# %%
df_1=pd.DataFrame({
    "States": grouped_data["state"].unique(),
    "# Mass Shooting":grouped_data["state"].count()
})
df_1.head()
# Out:
#                     States  # Mass Shooting
# state
#  California  [ California]               10
#  Colorado      [ Colorado]                3
#  Florida        [ Florida]                5
#  Illinois      [ Illinois]                2
#  Kansas          [ Kansas]                1

# %%
df_1=df_1.sort_values('# Mass Shooting', ascending = False)
df_2=df_1[:5].copy()

new_row = pd.DataFrame(data = {
    'States' : ['Others'],
    '# Mass Shooting' : [df_1['# Mass Shooting'][5:].sum()]
})

df_2 = pd.concat([df_2, new_row])
df_2
# Out:
#                         States  # Mass Shooting
#  California      [ California]               10
#  Texas                [ Texas]                6
#  Florida            [ Florida]                5
#  Pennsylvania  [ Pennsylvania]                4
#  Maryland          [ Maryland]                3
# 0                       Others               20

# %%
plt.pie(df_2["# Mass Shooting"],labels=df_2["States"],autopct="%1.1f%%",shadow=True, startangle=60)
plt.title("Last Five Years Incidents")
#plt.savefig("PercentangeStates.png")
# Out:
# Text(0.5, 1.0, 'Last Five Years Incidents')
